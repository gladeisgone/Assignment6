# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("diamonds.csv")
diamonds = df.copy()

# %%
df.head(10)
# shows first 5 entries
#df.tail(4)
# shows last 4 entries
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z  \
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39
#
#       volume
# 0  38.202030
# 1  34.505856
# 2  38.076885
# 3  46.724580
# 4  51.917250
# 5  38.693952
# 6  38.830870
# 7  42.321081
# 8  36.425214
# 9  38.718000

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# carat         float64
# cut            object
# color          object
# clarity        object
# depth         float64
# table         float64
# price           int64
# x             float64
# y             float64
# z             float64
# dtype: object

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df = df.drop(['Unnamed: 0'], axis=1)
print(df.head(5))
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df['volume'] = df['x']*df['y']*df['z']
df.head()
# Out:
# /var/folders/7y/g3pjs4gs09g2c25_09v7lvyr0000gn/T/ipykernel_77461/1889927536.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#       volume
# 0  38.202030
# 1  34.505856
# 2  38.076885
# 3  46.724580
# 4  51.917250

# %%
df = df[(df[['x','y','z']] != 0).all(axis=1)]

# %%
corr = df.corr()
sns.heatmap(data=corr, square=True , annot=True, cbar=True)
# Out:
# /var/folders/7y/g3pjs4gs09g2c25_09v7lvyr0000gn/T/ipykernel_77461/2394069292.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <AxesSubplot: >

# %%
sns.catplot(x='cut', y='price', data=df, kind='box' ,aspect=2.5 )

# %% [markdown]
# ## Summary
#
# So for my assignment I chose to work with a dataset about Diamonds. I wanted to answer if the carat or cut type correlates to price at all. As you can see from the data it seems as if depth is heavily correlated with price. I beleieve this is due to if the diamonds depth is too large or small it will appear more dark and will not return an attractive amount of light. We can also see that the price of the diamond is is heavily corelated to carat and dimensions. From the second visualization we can see that Premium cut diamonds are the most expensive followed by Very Good cut. From What I've gathered I do believe that Carat/Cut type correlates to the pricing.
